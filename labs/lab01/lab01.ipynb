# %%
println(typeof(3))
println(typeof(3.5))
println(typeof(3/3.5))
println(typeof(√3 + 4im))
println(typeof(π))
# Out:
# Int64
# Float64
# Float64
# ComplexF64
# Irrational{:π}

# %%
for T in [Int8, Int16, Int32, Int64, Int128, UInt8, UInt16, UInt32, UInt64, UInt128]
    println("$(lpad(T, 7)): [$(typemin(T)), $(typemax(T))]")
end
# Out:
#    Int8: [-128, 127]
#   Int16: [-32768, 32767]
#   Int32: [-2147483648, 2147483647]
#   Int64: [-9223372036854775808, 9223372036854775807]
#  Int128: [-170141183460469231731687303715884105728, 170141183460469231731687303715884105727]
#   UInt8: [0, 255]
#  UInt16: [0, 65535]
#  UInt32: [0, 4294967295]
#  UInt64: [0, 18446744073709551615]
# UInt128: [0, 340282366920938463463374607431768211455]

# %%
println(Int64(2.0))
println(Char(2))
println(convert(Int64, 2.0))
println(convert(Char, 2))
println(Bool(1))
println(Bool(0))
println(promote(Int8(1), Float16(4.5), Float32(4.1)))
# Out:
# 2
#
# 2
#
# true
# false
# (1.0f0, 4.5f0, 4.1f0)

# %%
function f(x)
    return x^2
end
println(f(4))

g(x) = x^2
println(g(5))
# Out:
# 16
# 25

# %%
a = [4 7 6] # вектор-строка
b = [1, 2, 3] # вектор-столбец
println(a[2], " ", b[2])

Am = [1 2; 3 4]
println(Am[1,1], " ", Am[1,2], " ", Am[2,1], " ", Am[2,2])

aa = [1 2]
AA = [1 2; 3 4]
result = aa * AA * aa'
println(result)
# Out:
# 7 2
# 1 2 3 4
# [27;;]

# %%
# Чтение/запись
write("test.txt", "Hello Julia")
content = read("test.txt", String)
println(content)

# Parse
num = parse(Int, "123")
println(num + 1)

# Математика
println(10 % 3) # остаток
println(2 ^ 10) # степень
# Out:
# Hello Julia
# 124
# 1
# 1024
